# %% [markdown]
# # Lab: Comparing tSNE and UMAP Dimension Reduction Models

# %%
# !pip install numpy==2.2.0
# !pip install pandas==2.2.3
# !pip install matplotlib==3.9.3
# !pip install plotly==5.24.1
# !pip install umap-learn==0.5.7
# Out:
# Requirement already satisfied: numpy==2.2.0 in c:\users\nensipansuriya\appdata\local\programs\python\python311\lib\site-packages (2.2.0)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\nensipansuriya\AppData\Local\Programs\Python\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\nensipansuriya\AppData\Local\Programs\Python\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\nensipansuriya\AppData\Local\Programs\Python\Python311\Lib\site-packages)
# Requirement already satisfied: pandas==2.2.3 in c:\users\nensipansuriya\appdata\local\programs\python\python311\lib\site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.23.2 in c:\users\nensipansuriya\appdata\local\programs\python\python311\lib\site-packages (from pandas==2.2.3) (2.2.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\nensipansuriya\appdata\local\programs\python\python311\lib\site-packages (from pandas==2.2.3) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\nensipansuriya\appdata\local\programs\python\python311\lib\site-packages (from pandas==2.2.3) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\nensipansuriya\appdata\local\programs\python\python311\lib\site-packages (from pandas==2.2.3) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\nensipansuriya\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil>=2.8.2->pandas==2.2.3) (1.17.0)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\nensipansuriya\AppData\Local\Programs\Python\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\nensipansuriya\AppData\Local\Programs\Python\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\nensipansuriya\AppData\Local\Programs\Python\Python311\Lib\site-packages)
# Collecting matplotlib==3.9.3
#   Using cached matplotlib-3.9.3-cp311-cp311-win_amd64.whl.metadata (11 kB)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\nensipansuriya\appdata\local\programs\python\python311\lib\site-packages (from matplotlib==3.9.3) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\nensipansuriya\appdata\local\programs\python\python311\lib\site-packages (from matplotlib==3.9.3) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\nensipansuriya\appdata\local\programs\python\python311\lib\site-packages (from matplotlib==3.9.3) (4.59.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\nensipansuriya\appdata\local\programs\python\python311\lib\site-packages (from matplotlib==3.9.3) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in c:\users\nensipansuriya\appdata\local\programs\python\python311\lib\site-packages (from matplotlib==3.9.3) (2.2.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\nensipansuriya\appdata\local\programs\python\python311\lib\site-packages (from matplotlib==3.9.3) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\nensipansuriya\appdata\local\programs\python\python311\lib\site-packages (from matplotlib==3.9.3) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\nensipansuriya\appdata\local\programs\python\python311\lib\site-packages (from matplotlib==3.9.3) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\nensipansuriya\appdata\local\programs\python\python311\lib\site-packages (from matplotlib==3.9.3) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\nensipansuriya\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil>=2.7->matplotlib==3.9.3) (1.17.0)
# Using cached matplotlib-3.9.3-cp311-cp311-win_amd64.whl (7.8 MB)
# Installing collected packages: matplotlib
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.10.5
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\nensipansuriya\AppData\Local\Programs\Python\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\nensipansuriya\AppData\Local\Programs\Python\Python311\Lib\site-packages)
# error: uninstall-no-record-file
#
# × Cannot uninstall matplotlib 3.10.5
# ╰─> The package's contents are unknown: no RECORD file was found for matplotlib.
#
# hint: You might be able to recover from this via: pip install --force-reinstall --no-deps matplotlib==3.10.5
# Collecting plotly==5.24.1
#   Downloading plotly-5.24.1-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\nensipansuriya\appdata\local\programs\python\python311\lib\site-packages (from plotly==5.24.1) (9.1.2)
# Requirement already satisfied: packaging in c:\users\nensipansuriya\appdata\local\programs\python\python311\lib\site-packages (from plotly==5.24.1) (25.0)
# Downloading plotly-5.24.1-py3-none-any.whl (19.1 MB)
#    ---------------------------------------- 0.0/19.1 MB ? eta -:--:--
#     --------------------------------------- 0.3/19.1 MB ? eta -:--:--
#    - -------------------------------------- 0.8/19.1 MB 2.1 MB/s eta 0:00:09
#    - -------------------------------------- 0.8/19.1 MB 2.1 MB/s eta 0:00:09
#    -- ------------------------------------- 1.0/19.1 MB 1.3 MB/s eta 0:00:15
#    -- ------------------------------------- 1.3/19.1 MB 1.2 MB/s eta 0:00:15
#    --- ------------------------------------ 1.6/19.1 MB 1.2 MB/s eta 0:00:15
#    --- ------------------------------------ 1.8/19.1 MB 1.2 MB/s eta 0:00:15
#    ---- ----------------------------------- 2.1/19.1 MB 1.3 MB/s eta 0:00:14
#    ----- ---------------------------------- 2.6/19.1 MB 1.3 MB/s eta 0:00:13
#    ------ --------------------------------- 2.9/19.1 MB 1.4 MB/s eta 0:00:12
#    ------ --------------------------------- 3.1/19.1 MB 1.4 MB/s eta 0:00:12
#    ------- -------------------------------- 3.7/19.1 MB 1.4 MB/s eta 0:00:11
#    -------- ------------------------------- 3.9/19.1 MB 1.4 MB/s eta 0:00:11
#    -------- ------------------------------- 4.2/19.1 MB 1.5 MB/s eta 0:00:11
#    --------- ------------------------------ 4.5/19.1 MB 1.5 MB/s eta 0:00:11
#    --------- ------------------------------ 4.7/19.1 MB 1.4 MB/s eta 0:00:11
#    ---------- ----------------------------- 5.0/19.1 MB 1.4 MB/s eta 0:00:11
#    ----------- ---------------------------- 5.2/19.1 MB 1.4 MB/s eta 0:00:11
#    ----------- ---------------------------- 5.5/19.1 MB 1.4 MB/s eta 0:00:10
#    ------------ --------------------------- 5.8/19.1 MB 1.4 MB/s eta 0:00:10
#    ------------ --------------------------- 6.0/19.1 MB 1.4 MB/s eta 0:00:10
#    ------------- -------------------------- 6.6/19.1 MB 1.4 MB/s eta 0:00:09
#    -------------- ------------------------- 7.1/19.1 MB 1.4 MB/s eta 0:00:09
#    -------------- ------------------------- 7.1/19.1 MB 1.4 MB/s eta 0:00:09
#    --------------- ------------------------ 7.3/19.1 MB 1.4 MB/s eta 0:00:09
#    --------------- ------------------------ 7.6/19.1 MB 1.4 MB/s eta 0:00:09
#    ---------------- ----------------------- 7.9/19.1 MB 1.4 MB/s eta 0:00:09
#    ----------------- ---------------------- 8.4/19.1 MB 1.4 MB/s eta 0:00:08
#    ----------------- ---------------------- 8.4/19.1 MB 1.4 MB/s eta 0:00:08
#    ------------------ --------------------- 8.9/19.1 MB 1.4 MB/s eta 0:00:08
#    ------------------- -------------------- 9.4/19.1 MB 1.4 MB/s eta 0:00:07
#    -------------------- ------------------- 9.7/19.1 MB 1.4 MB/s eta 0:00:07
#    -------------------- ------------------- 10.0/19.1 MB 1.4 MB/s eta 0:00:07
#    ---------------------- ----------------- 10.5/19.1 MB 1.4 MB/s eta 0:00:06
#    ----------------------- ---------------- 11.0/19.1 MB 1.5 MB/s eta 0:00:06
#    ------------------------ --------------- 11.8/19.1 MB 1.5 MB/s eta 0:00:05
#    ------------------------- -------------- 12.3/19.1 MB 1.6 MB/s eta 0:00:05
#    --------------------------- ------------ 13.1/19.1 MB 1.6 MB/s eta 0:00:04
#    ---------------------------- ----------- 13.6/19.1 MB 1.6 MB/s eta 0:00:04
#    ----------------------------- ---------- 13.9/19.1 MB 1.6 MB/s eta 0:00:04
#    ------------------------------ --------- 14.4/19.1 MB 1.7 MB/s eta 0:00:03
#    ------------------------------- -------- 14.9/19.1 MB 1.7 MB/s eta 0:00:03
#    -------------------------------- ------- 15.5/19.1 MB 1.7 MB/s eta 0:00:03
#    --------------------------------- ------ 15.7/19.1 MB 1.7 MB/s eta 0:00:02
#    ---------------------------------- ----- 16.3/19.1 MB 1.7 MB/s eta 0:00:02
#    ---------------------------------- ----- 16.5/19.1 MB 1.7 MB/s eta 0:00:02
#    ----------------------------------- ---- 17.0/19.1 MB 1.7 MB/s eta 0:00:02
#    ------------------------------------ --- 17.6/19.1 MB 1.7 MB/s eta 0:00:01
#    ------------------------------------- -- 18.1/19.1 MB 1.7 MB/s eta 0:00:01
#    ---------------------------------------  18.9/19.1 MB 1.8 MB/s eta 0:00:01
#    ---------------------------------------- 19.1/19.1 MB 1.8 MB/s  0:00:10
# Installing collected packages: plotly
#   Attempting uninstall: plotly
#     Found existing installation: plotly 6.3.0
#     Uninstalling plotly-6.3.0:
#       Successfully uninstalled plotly-6.3.0
# Successfully installed plotly-5.24.1
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\nensipansuriya\AppData\Local\Programs\Python\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\nensipansuriya\AppData\Local\Programs\Python\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\nensipansuriya\AppData\Local\Programs\Python\Python311\Lib\site-packages)
# Collecting umap-learn==0.5.7
#   Downloading umap_learn-0.5.7-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: numpy>=1.17 in c:\users\nensipansuriya\appdata\local\programs\python\python311\lib\site-packages (from umap-learn==0.5.7) (2.2.0)
# Requirement already satisfied: scipy>=1.3.1 in c:\users\nensipansuriya\appdata\local\programs\python\python311\lib\site-packages (from umap-learn==0.5.7) (1.16.1)
# Requirement already satisfied: scikit-learn>=0.22 in c:\users\nensipansuriya\appdata\local\programs\python\python311\lib\site-packages (from umap-learn==0.5.7) (1.6.0)
# Requirement already satisfied: numba>=0.51.2 in c:\users\nensipansuriya\appdata\local\programs\python\python311\lib\site-packages (from umap-learn==0.5.7) (0.61.2)
# Requirement already satisfied: pynndescent>=0.5 in c:\users\nensipansuriya\appdata\local\programs\python\python311\lib\site-packages (from umap-learn==0.5.7) (0.5.13)
# Requirement already satisfied: tqdm in c:\users\nensipansuriya\appdata\local\programs\python\python311\lib\site-packages (from umap-learn==0.5.7) (4.67.1)
# Requirement already satisfied: llvmlite<0.45,>=0.44.0dev0 in c:\users\nensipansuriya\appdata\local\programs\python\python311\lib\site-packages (from numba>=0.51.2->umap-learn==0.5.7) (0.44.0)
# Requirement already satisfied: joblib>=0.11 in c:\users\nensipansuriya\appdata\local\programs\python\python311\lib\site-packages (from pynndescent>=0.5->umap-learn==0.5.7) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\nensipansuriya\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn>=0.22->umap-learn==0.5.7) (3.6.0)
# Requirement already satisfied: colorama in c:\users\nensipansuriya\appdata\roaming\python\python311\site-packages (from tqdm->umap-learn==0.5.7) (0.4.6)
# Downloading umap_learn-0.5.7-py3-none-any.whl (88 kB)
# Installing collected packages: umap-learn
#   Attempting uninstall: umap-learn
#     Found existing installation: umap-learn 0.5.9.post2
#     Uninstalling umap-learn-0.5.9.post2:
#       Successfully uninstalled umap-learn-0.5.9.post2
# Successfully installed umap-learn-0.5.7
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\nensipansuriya\AppData\Local\Programs\Python\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\nensipansuriya\AppData\Local\Programs\Python\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\nensipansuriya\AppData\Local\Programs\Python\Python311\Lib\site-packages)

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.datasets import make_blobs
from sklearn.preprocessing import StandardScaler

#import umap.umap_ as UMAP 
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA

import plotly.express as px
from sklearn.datasets import make_blobs

# %% [markdown]
# ### Generate synthetic data with four clusters in a 3D space

# %%
# CLuster centers:
centers = [ [ 2, -6, -6],
            [-1,  9,  4],
            [-8,  7,  2],
            [ 4,  7,  9] ]

# Cluster standard deviations:
cluster_std=[1,1,2,3.5]

# Make the blobs and return the data and the blob labels
X, labels_ = make_blobs(n_samples=500, centers=centers, n_features=3, cluster_std=cluster_std, random_state=42)

# %% [markdown]
# ### Display the data in an interactive Plotly 3D scatter plot

# %%
# Create a DataFrame for Plotly
df = pd.DataFrame(X, columns=['X', 'Y', 'Z'])

# Create interactive 3D scatter plot
fig = px.scatter_3d(df, x='X', y='Y', z='Z', color=labels_.astype(str) ,  opacity=0.7,  color_discrete_sequence=px.colors.qualitative.G10, title="3D Scatter Plot of Four Blobs")

fig.update_traces(marker=dict(size=5, line=dict(width=1, color='black')), showlegend=False)
fig.update_layout(coloraxis_showscale=False, width=1000, height=800)  # Remove color bar, resize plot

fig.show()

# %% [markdown]
# ### Interact with the plot
# ### Exercise 1. What can you say about the four blobs?

# %% [markdown]
# - The blobs have varying densities.
# - One blob is distinct from the others.
# - The two largest blobs are distinct from each other, but both have a bit of overlap with the other blob between them.

# %% [markdown]
# ### Exercise 2. Standardize the data to prepare it for the three projection methods.

# %%
# Standardize the data 
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %% [markdown]
# ### Apply t-SNE to reduce the dimensionality to 2D

# %%
tsne = TSNE(n_components=2, random_state=42, perplexity=30, max_iter=1000)
X_tsne = tsne.fit_transform(X_scaled)

# %% [markdown]
# ### Let's plot the 2D t-SNE result

# %%
fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(111)
ax.scatter(X_tsne[:, 0], X_tsne[:, 1], c=labels_, cmap='viridis', s=50, alpha=0.7, edgecolor='k')
ax.set_title("2D t-SNE Projection of 3D Data")
ax.set_xlabel("t-SNE Component 1")
ax.set_ylabel("t-SNE Component 2")
ax.set_xticks([])
ax.set_yticks([])
plt.show()

# %% [markdown]
# ### Exercise 3. What can you say about this t-SNE result?

# %% [markdown]
# - t-SNE projected the data into four distinct clusters, although the original data had some overlap between a few clusters.
# - You can see that some of the points ended up in the "wrong" cluster, although to be fair, t-SNE has no knowledge of which clusters the points actually belong to.
# - All the clusters have similar densities.
# - Two of the blobs are distinct from each other but "gave up" some of their points to the blob they originally had overlapped with.
# - A "perfect" result would not completely separate the overlaps between blobs.
# - Notice that the distance between the blobs is consistent with the degree to which they were originally separated.

# %% [markdown]
# ## Compare UMAP and PCA dimensionality reduction to two dimensions

# %%
# Apply UMAP to reduce the dimensionality to 2D
umap_model = UMAP.UMAP(n_components=2, random_state=42, min_dist=0.5, spread=1,n_jobs=1)

X_umap = umap_model.fit_transform(X_scaled)

# Plot the 2D UMAP projection result 
fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(111)
ax.scatter(X_umap[:, 0], X_umap[:, 1], c=labels_, cmap='viridis', s=50, alpha=0.7, edgecolor='k')

ax.set_title("2D UMAP Projection of 3D Data")
ax.set_xlabel("UMAP Component 1", )
ax.set_ylabel("UMAP Component 2", )
ax.set_xticks([])
ax.set_yticks([])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 2
#       1 # Apply UMAP to reduce the dimensionality to 2D
# ----> 2 umap_model = UMAP.UMAP(n_components=2, random_state=42, min_dist=0.5, spread=1,n_jobs=1)
#       4 X_umap = umap_model.fit_transform(X_scaled)
#       6 # Plot the 2D UMAP projection result
#
# NameError: name 'UMAP' is not defined

# %% [markdown]
# ### Exercise 4. What can you say about this UMAP result?

# %% [markdown]
# - UMAP correctly projected the data into four partially distinct clusters, with one cluster completely distinct from the others.
# - Unlike t-SNE, it has preserved the connectedness that the original data had with the partially overlapping clusters.
# - You can see that, like t-SNE, some of the points ended up in the "wrong" cluster.
# - Again, like t-SNE, all the clusters have similar densities.
# - A "perfect" result would not completely separate the overlaps between blobs, because they actually do overlap in the original feature space.
# - The distance between the clusters is again consistent with the degree to which they were originally separated.

# %%
# Apply PCA to reduce the dimensionality to 2D
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)


fig = plt.figure(figsize=(8, 6))

# Plot the 2D PCA result (right)
ax2 = fig.add_subplot(111)
scatter2 = ax2.scatter(X_pca[:, 0], X_pca[:, 1], c=labels_, cmap='viridis', s=50, alpha=0.7, edgecolor='k')
ax2.set_title("2D PCA Projection of 3-D Data")
ax2.set_xlabel("PCA 1")
ax2.set_ylabel("PCA 2")
ax2.set_xticks([])
ax2.set_yticks([])
plt.show()

# %% [markdown]
# ### Exercise 5. What can you say about this PCA result?

# %% [markdown]
# - PCA faithfully preserved the relative blob densities.
# - PCA also preserved the relative separation between blobs.
# - The distance between the clusters is very consistent with the degree to which they were originally separated.
# - PCA and t-SNE took very little time to complete compared to UMAP.
# - IMNSHO, PCA outperformed both t-SNE and UMAP in this experiment.
# This points to a common tendency to want to implement more advanced algorithms.
# The default result is not always an improvement over the simpler established methods.
